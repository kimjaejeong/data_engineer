# %%
import os
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import pandas as pd
path = "/content/gdrive/MyDrive/data_engineering/data/"
df = pd.read_csv(path + "test.csv");df
# Out:
#      Name  age
# 0   Krish   10
# 1  sandra   21
# 2     kjj   28

# %%
# !pip install pyspark

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Practise").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7288cb3fa07d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv(path + "test.csv")

# %%
df_pyspark = spark.read.option('header', 'true').csv(path + "test.csv")
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('DataFrame').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7288cb3fa07d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
## Read the dataset
df_pyspark = spark.read.option('header', 'true').csv(path + 'test.csv', inferSchema = True)
df_pyspark
# Out:
# DataFrame[Name: string, age: int]

# %%
## Check the schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)

# %%
df_pyspark = spark.read.csv(path + "test.csv", header = True, inferSchema=True)
df_pyspark.show()
# Out:
# +------+---+
# |  Name|age|
# +------+---+
# | Krish| 10|
# |sandra| 21|
# |   kjj| 28|
# +------+---+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# ['Name', 'age']

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Krish', age=10),
#  Row(Name='sandra', age=21),
#  Row(Name='kjj', age=28)]

# %%
df_pyspark.select(['Name', 'age']).show()
# Out:
# +------+---+
# |  Name|age|
# +------+---+
# | Krish| 10|
# |sandra| 21|
# |   kjj| 28|
# +------+---+

# %%
df_pyspark['Name']
# Out:
# Column<'Name'>

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('age', 'int')]

# %%
df_pyspark.describe().show()
# Out:
# +-------+------+------------------+
# |summary|  Name|               age|
# +-------+------+------------------+
# |  count|     3|                 3|
# |   mean|  null|19.666666666666668|
# | stddev|  null| 9.073771725877465|
# |    min| Krish|                10|
# |    max|sandra|                28|
# +-------+------+------------------+

# %%
### Adding Columns in DataFrame
df_pyspark = df_pyspark.withColumn("age after 2 year", df_pyspark['age'] + 2)

# %%
df_pyspark.show()
# Out:
# +------+---+----------------+
# |  Name|age|age after 2 year|
# +------+---+----------------+
# | Krish| 10|              12|
# |sandra| 21|              23|
# |   kjj| 28|              30|
# +------+---+----------------+

# %%
### Drop the columns
df_pyspark = df_pyspark.drop("age after 2 year")

# %%
df_pyspark.show()
# Out:
# +------+---+
# |  Name|age|
# +------+---+
# | Krish| 10|
# |sandra| 21|
# |   kjj| 28|
# +------+---+

# %%
### Rename the columns
df_pyspark = df_pyspark.withColumnRenamed("Name", "revise_name")

# %%
df_pyspark.show()
# Out:
# +-----------+---+
# |revise_name|age|
# +-----------+---+
# |      Krish| 10|
# |     sandra| 21|
# |        kjj| 28|
# +-----------+---+
